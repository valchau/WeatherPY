# %% [markdown]
# # Deliverable 2. Create a Customer Travel Destinations Map
#
# ----
#
# 1. Create a folder called `Vacation_Search` to save all the files related with this deliverable.
#
# 2. Download the `Vacation_Search_starter_code.ipynb` Jupyter notebook,save it into your `Vacation_Search folder`, and rename it as `Vacation_Search.ipynb`.
#
# 3. In the `Vacation_Search.ipynb` file, ensure that the dependencies and the Geoapify API key is imported correctly.
#
# 4. From the `Weather_Database` folder you created in the "Deliverable 1," import the `WeatherPy_Database.csv` file as a Pandas DataFrame named `city_data_df`.
#
# 5. Write two input statements that prompt the user to enter their minimum and maximum temperature criteria for their vacation.
#
# 6. Create a new Pandas DataFrame by using the `loc` Pandas method to filter the `city_data_df` DataFrame for temperature criteria  collected. Name the DataFrame as `preferred_cities_df`.
#
# 7. Create a new Pandas DataFrame named `clean_travel_cities` by using the Pandas `dropna` function on the `preferred_cities_df` to drop any empty rows.
#
# 8. Use the `copy` Pandas function to create a new DataFrame, called `hotel_df`, by copying the following columns from the `clean_travel_cities` DataFrame: "City", "Country", "Max Temp", "Current Description", "Lat", "Lng".
#
# 9. Add a new empty column named `Hotel Name` to the `hotel_df` DataFrame.
#
# 10. Review the hotel search parameters provided. These parameters are the same we used in this module; you'll use them to search for a hotel for each city.
#
# 11. Use a for loop to iterate through the `hotel_df` DataFrame. Retrieve the latitude and longitude of each city and use the Geoapify API to find the nearest hotel based on the search parameters provided, then add the hotel name to the `hotel_df` DataFrame. If a hotel isn't found, set the hotel name as "No hotel found".  <-- cannot get this step to work
#
# 12. Drop any rows in the `hotel_df` DataFrame where a hotel name is not found and store the resulting data into a new DataFrame named `clean_hotel_df`.
#
# 13. Create an CSV file to store the `clean_hotel_df` DataFrame as `WeatherPy_vacation.csv` in the Vacation_Search folder.
#
# 14. Use GeoViews to create a map that displays a point for every city in the `clean_hotel_df` DataFrame. In the point for each city add:
#
#     * The city name
#
#     * The country code
#
#     * The weather description
#
#     * The point's size should be the maximum temperature for the city
#
# 15. Take a screenshot of your map and save it to the `Vacation_Search` folder as `WeatherPy_vacation_map.png`.
#
# ---

# %% [markdown]
# ## Ensure that the dependencies and the Geoapify API key is imported correctly

# %%
import pandas as pd
import requests

# Turn off warning messages
import warnings
warnings.filterwarnings("ignore")

# Import API key. I tested. it does retrieve the key
from config import geoapify_key

# %% [markdown]
# ## From the `Weather_Database` folder you created in the "Deliverable 1," import the `WeatherPy_Database.csv` file as a Pandas DataFrame named `city_data_df`

# %%
# Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("../Weather_Database/WeatherPy_Database.csv")

# Display sample data
city_data_df.head(10)
# Out:
#    City_ID            City Country                 Date      Lat       Lng  \
# 0        0          Castro      BR  2022-12-25 00:31:33 -24.7911  -50.0119
# 1        1   Mar Del Plata      AR  2022-12-25 00:27:57 -38.0023  -57.5575
# 2        2      Turukhansk      RU  2022-12-25 00:31:33  65.8167   87.9833
# 3        3         Mandali      IQ  2022-12-25 00:31:34  33.7499   45.5541
# 4        4    Punta Arenas      CL  2022-12-25 00:30:01 -53.1500  -70.9167
# 5        5       Busselton      AU  2022-12-25 00:31:35 -33.6500  115.3333
# 6        6      Nikolskoye      RU  2022-12-25 00:31:35  59.7035   30.7861
# 7        7        Hermanus      ZA  2022-12-25 00:31:35 -34.4187   19.2345
# 8        8     Provideniya      RU  2022-12-25 00:31:36  64.3833 -173.3000
# 9        9  Roanoke Rapids      US  2022-12-25 00:31:37  36.4615  -77.6542
#
#    Max Temp  Humidity  Cloudiness  Wind Speed Current Description
# 0     60.85        98          89        9.17     overcast clouds
# 1     62.10        70           0       14.00          light rain
# 2      0.43        93         100       11.01     overcast clouds
# 3     51.67        87          75        5.46          light rain
# 4     53.71        54          20       27.63          few clouds
# 5     72.21        55          19        5.97          few clouds
# 6     28.80        92          26        6.87    scattered clouds
# 7     58.80        72          72        9.24          light rain
# 8     12.38        83           9       13.56           clear sky
# 9     25.68        68           0       10.49           clear sky

# %% [markdown]
# ## Write two input statements that prompt the user to enter their minimum and maximum temperature criteria for their vacation

# %%
# Prompt the user to enter minimum and maximum temperature criteria.
min_temp = float(input("What is the minimum temperature in Fahrenheit that you would like for your vacation? "))
max_temp = float(input("What is the maximum temperature in Fahrenheit that you would like for your vacation? "))
# Out:
# What is the minimum temperature in Fahrenheit that you would like for your vacation? 65
# What is the maximum temperature in Fahrenheit that you would like for your vacation? 78

# %% [markdown]
# ## Create a new Pandas DataFrame by using the `loc` Pandas method to filter the `city_data_df` DataFrame for temperature criteria  collected. Name the DataFrame as `preferred_cities_df`

# %%
# Filter the city_data_df DataFrame to find the cities that fit the criteria using the loc method.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]

# Display sample data
preferred_cities_df.head(15)
# Out:
#     City_ID             City Country                 Date      Lat       Lng  \
# 5         5        Busselton      AU  2022-12-25 00:31:35 -33.6500  115.3333
# 11       11            Podor      MR  2022-12-25 00:31:38  16.6527  -14.9587
# 12       12          Mataura      NZ  2022-12-25 00:31:38 -46.1927  168.8643
# 18       18            Pisco      PE  2022-12-25 00:31:41 -13.7000  -76.2167
# 23       23  Arraial Do Cabo      BR  2022-12-25 00:28:25 -22.9661  -42.0278
# 26       26       Sao Filipe      CV  2022-12-25 00:31:45  14.8961  -24.4956
# 29       29            Kathu      TH  2022-12-25 00:31:46   7.9178   98.3332
# 40       40           Hobart      AU  2022-12-25 00:31:36 -42.8794  147.3294
# 44       44     Port Lincoln      AU  2022-12-25 00:31:53 -34.7333  135.8667
# 58       58         Bengkulu      ID  2022-12-25 00:33:01  -3.8004  102.2655
# 59       59     Puerto Ayora      EC  2022-12-25 00:33:01  -0.7393  -90.3518
# 63       63          Rikitea      PF  2022-12-25 00:33:03 -23.1203 -134.9692
# 71       71       Nouadhibou      MR  2022-12-25 00:33:07  20.9310  -17.0347
# 74       74        Coihaique      CL  2022-12-25 00:33:09 -45.5752  -72.0662
# 76       76       Kaitangata      NZ  2022-12-25 00:33:09 -46.2817  169.8464
#
#     Max Temp  Humidity  Cloudiness  Wind Speed Current Description
# 5      72.21        55          19        5.97          few clouds
# 11     68.40        19           0       10.51           clear sky
# 12     72.07        45          55        6.71       broken clouds
# 18     69.85        83           0        8.05           clear sky
# 23     73.40        88          53       12.97       broken clouds
# 26     72.86        60          65       13.69       broken clouds
# 29     73.22        74          98       16.55     overcast clouds
# 40     75.06        50          40       12.66    scattered clouds
# 44     73.38        48           0        3.47           clear sky
# 58     76.01        77         100        3.62     overcast clouds
# 59     73.54        93          41        3.00    scattered clouds
# 63     77.31        76          24       10.47          few clouds
# 71     67.98        42           0       12.66           clear sky
# 74     69.75        52           0        2.30           clear sky
# 76     68.79        57          27        4.05    scattered clouds

# %% [markdown]
# ## Create a new Pandas DataFrame named `clean_travel_cities` by using the Pandas `dropna` function on the `preferred_cities_df` to drop any empty rows

# %%
# Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
clean_travel_cities_df = preferred_cities_df.dropna()

# Display sample data
clean_travel_cities_df.head(10)
# Out:
#     City_ID             City Country                 Date      Lat       Lng  \
# 5         5        Busselton      AU  2022-12-25 00:31:35 -33.6500  115.3333
# 11       11            Podor      MR  2022-12-25 00:31:38  16.6527  -14.9587
# 12       12          Mataura      NZ  2022-12-25 00:31:38 -46.1927  168.8643
# 18       18            Pisco      PE  2022-12-25 00:31:41 -13.7000  -76.2167
# 23       23  Arraial Do Cabo      BR  2022-12-25 00:28:25 -22.9661  -42.0278
# 26       26       Sao Filipe      CV  2022-12-25 00:31:45  14.8961  -24.4956
# 29       29            Kathu      TH  2022-12-25 00:31:46   7.9178   98.3332
# 40       40           Hobart      AU  2022-12-25 00:31:36 -42.8794  147.3294
# 44       44     Port Lincoln      AU  2022-12-25 00:31:53 -34.7333  135.8667
# 58       58         Bengkulu      ID  2022-12-25 00:33:01  -3.8004  102.2655
#
#     Max Temp  Humidity  Cloudiness  Wind Speed Current Description
# 5      72.21        55          19        5.97          few clouds
# 11     68.40        19           0       10.51           clear sky
# 12     72.07        45          55        6.71       broken clouds
# 18     69.85        83           0        8.05           clear sky
# 23     73.40        88          53       12.97       broken clouds
# 26     72.86        60          65       13.69       broken clouds
# 29     73.22        74          98       16.55     overcast clouds
# 40     75.06        50          40       12.66    scattered clouds
# 44     73.38        48           0        3.47           clear sky
# 58     76.01        77         100        3.62     overcast clouds

# %% [markdown]
# ## Use the `copy` Pandas function to create a new DataFrame, called `hotel_df`, by copying the following columns from the `clean_travel_cities` DataFrame: "City", "Country", "Max Temp", "Current Description", "Lat", "Lng"

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = clean_travel_cities_df[["City", "Country", "Max Temp", "Current Description", "Lat", "Lng"]].copy()

# %% [markdown]
# ## Add a new empty column named `Hotel Name` to the `hotel_df` DataFrame

# %%
# Create a new column "Hotel Name".
hotel_df["Hotel Name"] = ""

# Display sample data
hotel_df.head(10)
# Out:
#                City Country  Max Temp Current Description      Lat       Lng  \
# 5         Busselton      AU     72.21          few clouds -33.6500  115.3333
# 11            Podor      MR     68.40           clear sky  16.6527  -14.9587
# 12          Mataura      NZ     72.07       broken clouds -46.1927  168.8643
# 18            Pisco      PE     69.85           clear sky -13.7000  -76.2167
# 23  Arraial Do Cabo      BR     73.40       broken clouds -22.9661  -42.0278
# 26       Sao Filipe      CV     72.86       broken clouds  14.8961  -24.4956
# 29            Kathu      TH     73.22     overcast clouds   7.9178   98.3332
# 40           Hobart      AU     75.06    scattered clouds -42.8794  147.3294
# 44     Port Lincoln      AU     73.38           clear sky -34.7333  135.8667
# 58         Bengkulu      ID     76.01     overcast clouds  -3.8004  102.2655
#
#    Hotel Name
# 5
# 11
# 12
# 18
# 23
# 26
# 29
# 40
# 44
# 58

# %%
# Set the output file name
output_data_file = "Hotel_df.csv"

# Export the hotel DataFrame into a CSV file so I can see it works! And yes this file is correct!!!
# Everything works UNTIL I try hvplot~ Then it stops working entirely
hotel_df.to_csv(output_data_file, index_label="City_ID")

# %% [markdown]
# ## Review the hotel search parameters provided. These parameters are the same we used in this module; you'll use them to search for a hotel for each city

# %%
from config import geoapify_key
import hvplot.pandas
radius = 5000
params = {
    "categories":"accommodation.hotel",
    "apiKey": geoapify_key,
    "limit":20
}
print("completed import of hvplot")
# Out:
# completed import of hvplot

# %% [markdown]
# ## Use a for loop to iterate through the `hotel_df` DataFrame. Retrieve the latitude and longitude of each city and use the Geoapify API to find the nearest hotel based on the search parameters provided, then add the hotel name to the `hotel_df` DataFrame. If a hotel isn't found, set the hotel name as "No hotel found"

# %%
# get the saved file so that I don't have to keep re running the top part of this script
#hotel_saved_df = pd.read_csv("Hotel_df.csv")
# hotel_saved_df.head(20)

# %%
# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # Get latitude and longitude from DataFrame.
    # print("getting Lat and Long data", index)
    latitude = row["Lat"]
    longitude = row["Lng"]
    
    # Add the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set up the base URL for the Geoapify Places API.
    base_url = "https://api.geoapify.com/v2/places"

    # Make request and retrieve the JSON data by using the params dictionary  VAC CANNOT GET DATA
    name_address  = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
        print(index,row["Hotel Name"])
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".that makes zero sense
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
       
        
print("End of hotel search")
# Out:
# Starting hotel search
# 11 La Cour du Fleuve
# 18 La Portada
# 26 Bela Vista
# 29 Tinidee Hotel
# 40 The Old Woolstore Apartment Motel
# 44 Boston Hotel
# 58 Dena Hotel
# 59 Hostal La Mirada De Solitario George
drop any rows in the `hotel_df` DataFrame where a hotel name is not found and store the resulting data into a new DataFrame named `clean_hotel_df`

# %%
# Drop the rows where there is no Hotel Name.
hotel_df.drop(hotel_df.index[(hotel_df["Hotel Name"] == "No hotel found")],axis=0,inplace=True)    
clean_hotel_df = hotel_df

# Display sample data
clean_hotel_df.head(20)
# Out:
#                City Country  Max Temp Current Description      Lat       Lng  \
# 11            Podor      MR     68.40           clear sky  16.6527  -14.9587
# 18            Pisco      PE     69.85           clear sky -13.7000  -76.2167
# 26       Sao Filipe      CV     72.86       broken clouds  14.8961  -24.4956
# 29            Kathu      TH     73.22     overcast clouds   7.9178   98.3332
# 40           Hobart      AU     75.06    scattered clouds -42.8794  147.3294
# 44     Port Lincoln      AU     73.38           clear sky -34.7333  135.8667
# 58         Bengkulu      ID     76.01     overcast clouds  -3.8004  102.2655
# 59     Puerto Ayora      EC     73.54    scattered clouds  -0.7393  -90.3518
# 63          Rikitea      PF     77.31          few clouds -23.1203 -134.9692
# 71       Nouadhibou      MR     67.98           clear sky  20.9310  -17.0347
# 80           Lompoc      US     72.01           clear sky  34.6391 -120.4579
# 82        Mahebourg      MU     77.29       broken clouds -20.4081   57.7000
# 84           Padang      ID     71.65     overcast clouds  -0.9492  100.3543
# 96     Ponta Do Sol      PT     65.71     overcast clouds  32.6667  -17.1000
# 97              Sur      OM     70.20           clear sky  22.5667   59.5289
# 99      New Norfolk      AU     74.71     overcast clouds -42.7826  147.0587
# 100      Hambantota      LK     77.34    scattered clouds   6.1241   81.1185
# 104         Cayenne      GF     73.44       broken clouds   4.9333  -52.3333
# 105  Port Shepstone      ZA     72.21       moderate rain -30.7414   30.4550
# 113         Ahipara      NZ     70.09     overcast clouds -35.1667  173.1667
#
#                                         Hotel Name
# 11                               La Cour du Fleuve
# 18                                      La Portada
# 26                                      Bela Vista
# 29                                   Tinidee Hotel
# 40               The Old Woolstore Apartment Motel
# 44                                    Boston Hotel
# 58                                      Dena Hotel
# 59            Hostal La Mirada De Solitario George
# 63                            Chez Bianca & Benoit
# 71                                  Hotel valencia
# 80   Embassy Suites by Hilton Lompoc Central Coast
# 82                                   Grand Bel Air
# 84                                    losmen Surya
# 96                          Estalagem Ponta do Sol
# 97                                       Sur Hotel
# 99                       Woodbridge on the Derwent
# 100                Oasis Aurweda Resort Hambathota
# 104                                  Central Hôtel
# 105                          The Spot Backpackers'
# 113                                    YHA Ahipara

# %% [markdown]
# ## Create an CSV file to store the `clean_hotel_df` DataFrame as `WeatherPy_vacation.csv` in the `Vacation_Search`` folder

# %%
# Create the output File (CSV)
output_data_file = "WeatherPy_vacation.csv"

# Export the City_Data into a csv
clean_hotel_df.to_csv(output_data_file, index_label="City_ID")

# %% [markdown]
# ## Use GeoViews to create a map that displays a point for every city in the `clean_hotel_df` DataFrame.
#
# In the point for each city add:
#
# * The city name
# * The country code
# * The weather description
# * The point's size should be the maximum temperature for the city

# %%
# Configure the map plot using tasks in 6.5.4 
#City_ID	City	Country	Max Temp	Current Description	Lat	Lng	Hotel Name
hotel_map = clean_hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    size = "Max Temp",
    scale = 1,
    color = "City",
    hover_cols = ["City", "Max Temp","Hotel Name", "Country", "Current Description"]
)

# Display the map using tasks in 6.5.4 
hotel_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Max Temp,Hotel Name,Country,Current Description)
