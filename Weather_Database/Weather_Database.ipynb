# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from citipy import citipy
from config import weather_api_key

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 743

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        current_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":current_description,
                          "Date": city_date})
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kaitangata
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | orthez
# Processing Record 4 of Set 1 | kenai
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | qaanaaq
# Processing Record 7 of Set 1 | saint george
# Processing Record 8 of Set 1 | zalha
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | sisimiut
# Processing Record 11 of Set 1 | punta arenas
# Processing Record 12 of Set 1 | port elizabeth
# Processing Record 13 of Set 1 | pevek
# Processing Record 14 of Set 1 | conde
# Processing Record 15 of Set 1 | gubkinskiy
# Processing Record 16 of Set 1 | thinadhoo
# Processing Record 17 of Set 1 | castro
# Processing Record 18 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 19 of Set 1 | dikson
# Processing Record 20 of Set 1 | zhigansk
# Processing Record 21 of Set 1 | port alfred
# Processing Record 22 of Set 1 | albany
# Processing Record 23 of Set 1 | muros
# Processing Record 24 of Set 1 | henties bay
# Processing Record 25 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 26 of Set 1 | samalaeulu
# City not found. Skipping...
# Processing Record 27 of Set 1 | barrow
# Processing Record 28 of Set 1 | tuktoyaktuk
# Processing Record 29 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 30 of Set 1 | karratha
# Processing Record 31 of Set 1 | hithadhoo
# Processing Record 32 of Set 1 | rio gallegos
# Processing Record 33 of Set 1 | yunjinghong
# City not found. Skipping...
# Processing Record 34 of Set 1 | libreville
# Processing Record 35 of Set 1 | mar del plata
# Processing Record 36 of Set 1 | clyde river
# Processing Record 37 of Set 1 | kapaa
# Processing Record 38 of Set 1 | lompoc
# Processing Record 39 of Set 1 | pasighat
# Processing Record 40 of Set 1 | klaksvik
# Processing Record 41 of Set 1 | akyab
# Processing Record 42 of Set 1 | leningradskiy
# Processing Record 43 of Set 1 | hobart
# Processing Record 44 of Set 1 | avarua
# Processing Record 45 of Set 1 | tornio
# Processing Record 46 of Set 1 | cape town
# Processing Record 47 of Set 1 | hilo
# Processing Record 48 of Set 1 | mahebourg
# Processing Record 49 of Set 1 | tasiilaq
# Processing Record 50 of Set 1 | port huron
# Processing Record 1 of Set 2 | carnarvon
# Processing Record 2 of Set 2 | stoyba
# City not found. Skipping...
# Processing Record 3 of Set 2 | bengkulu
# Processing Record 4 of Set 2 | zharkent
# Processing Record 5 of Set 2 | matamoros
# Processing Record 6 of Set 2 | parfino
# Processing Record 7 of Set 2 | yellowknife
# Processing Record 8 of Set 2 | owando
# Processing Record 9 of Set 2 | hermanus
# Processing Record 10 of Set 2 | jamestown
# Processing Record 11 of Set 2 | katima mulilo
# Processing Record 12 of Set 2 | vao
# Processing Record 13 of Set 2 | nemuro
# Processing Record 14 of Set 2 | biak
# Processing Record 15 of Set 2 | luderitz
# Processing Record 16 of Set 2 | utiroa
# City not found. Skipping...
# Processing Record 17 of Set 2 | palmer
# Processing Record 18 of Set 2 | yeppoon
# Processing Record 19 of Set 2 | bilma
# Processing Record 20 of Set 2 | adrar
# Processing Record 21 of Set 2 | gamba
# Processing Record 22 of Set 2 | chuy
# Processing Record 23 of Set 2 | ridgecrest
# Processing Record 24 of Set 2 | wilmington island
# Processing Record 25 of Set 2 | yamada
# Processing Record 26 of Set 2 | strelka
# Processing Record 27 of Set 2 | gafanha da encarnacao
# Processing Record 28 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 29 of Set 2 | avera
# Processing Record 30 of Set 2 | taseyevo
# Processing Record 31 of Set 2 | lebu
# Processing Record 32 of Set 2 | alekseyevskoye
# Processing Record 33 of Set 2 | srandakan
# Processing Record 34 of Set 2 | kununurra
# Processing Record 35 of Set 2 | bonnyville
# Processing Record 36 of Set 2 | digha
# Processing Record 37 of Set 2 | okha
# Processing Record 38 of Set 2 | atuona
# Processing Record 39 of Set 2 | katherine
# Processing Record 40 of Set 2 | faanui
# Processing Record 41 of Set 2 | xining
# Processing Record 42 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 43 of Set 2 | saint-philippe
# Processing Record 44 of Set 2 | poum
# Processing Record 45 of Set 2 | humaita
# Processing Record 46 of Set 2 | bredasdorp
# Processing Record 47 of Set 2 | ellisras
# Processing Record 48 of Set 2 | hurghada
# Processing Record 49 of Set 2 | arrecife
# Processing Record 50 of Set 2 | rawannawi
# City not found. Skipping...
# Processing Record 1 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 2 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 3 of Set 3 | sao felix do xingu
# Processing Record 4 of Set 3 | new norfolk
# Processing Record 5 of Set 3 | nikolskoye
# Processing Record 6 of Set 3 | obo
# Processing Record 7 of Set 3 | airai
# Processing Record 8 of Set 3 | butaritari
# Processing Record 9 of Set 3 | tiksi
# Processing Record 10 of Set 3 | pimenta bueno
# Processing Record 11 of Set 3 | camocim
# Processing Record 12 of Set 3 | nabire
# Processing Record 13 of Set 3 | hambantota
# Processing Record 14 of Set 3 | nome
# Processing Record 15 of Set 3 | nisia floresta
# Processing Record 16 of Set 3 | cap malheureux
# Processing Record 17 of Set 3 | acapulco
# Processing Record 18 of Set 3 | nhulunbuy
# Processing Record 19 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 20 of Set 3 | chaoyang
# Processing Record 21 of Set 3 | novyy urengoy
# Processing Record 22 of Set 3 | kayerkan
# Processing Record 23 of Set 3 | miraflores
# Processing Record 24 of Set 3 | vaini
# Processing Record 25 of Set 3 | kruisfontein
# Processing Record 26 of Set 3 | umba
# Processing Record 27 of Set 3 | saskylakh
# Processing Record 28 of Set 3 | mataura
# Processing Record 29 of Set 3 | georgetown
# Processing Record 30 of Set 3 | uruzgan
# Processing Record 31 of Set 3 | viligili
# City not found. Skipping...
# Processing Record 32 of Set 3 | pangai
# Processing Record 33 of Set 3 | oistins
# Processing Record 34 of Set 3 | bluff
# Processing Record 35 of Set 3 | melito di porto salvo
# Processing Record 36 of Set 3 | takaka
# Processing Record 37 of Set 3 | san antonio
# Processing Record 38 of Set 3 | norman wells
# Processing Record 39 of Set 3 | sinnamary
# Processing Record 40 of Set 3 | arraial do cabo
# Processing Record 41 of Set 3 | san cataldo
# Processing Record 42 of Set 3 | viedma
# Processing Record 43 of Set 3 | malacampa
# Processing Record 44 of Set 3 | balakliya
# Processing Record 45 of Set 3 | alofi
# Processing Record 46 of Set 3 | labuhan
# Processing Record 47 of Set 3 | chitipa
# Processing Record 48 of Set 3 | lavrentiya
# Processing Record 49 of Set 3 | ancud
# Processing Record 50 of Set 3 | isangel
# Processing Record 1 of Set 4 | pringsewu
# Processing Record 2 of Set 4 | severo-kurilsk
# Processing Record 3 of Set 4 | lulea
# Processing Record 4 of Set 4 | malpe
# Processing Record 5 of Set 4 | harper
# Processing Record 6 of Set 4 | provideniya
# Processing Record 7 of Set 4 | dingle
# Processing Record 8 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 9 of Set 4 | necochea
# Processing Record 10 of Set 4 | khatanga
# Processing Record 11 of Set 4 | manuk mangkaw
# Processing Record 12 of Set 4 | cidreira
# Processing Record 13 of Set 4 | emba
# Processing Record 14 of Set 4 | keuruu
# Processing Record 15 of Set 4 | kangalassy
# Processing Record 16 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 17 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 18 of Set 4 | kotka
# Processing Record 19 of Set 4 | westport
# Processing Record 20 of Set 4 | sadao
# Processing Record 21 of Set 4 | atbasar
# Processing Record 22 of Set 4 | menongue
# Processing Record 23 of Set 4 | mao
# Processing Record 24 of Set 4 | tuatapere
# Processing Record 25 of Set 4 | bambous virieux
# Processing Record 26 of Set 4 | bethel
# Processing Record 27 of Set 4 | merauke
# Processing Record 28 of Set 4 | bertoua
# Processing Record 29 of Set 4 | laguna
# Processing Record 30 of Set 4 | thompson
# Processing Record 31 of Set 4 | ilfracombe
# Processing Record 32 of Set 4 | guaymas
# Processing Record 33 of Set 4 | vardo
# Processing Record 34 of Set 4 | puerto ayora
# Processing Record 35 of Set 4 | port lincoln
# Processing Record 36 of Set 4 | marau
# Processing Record 37 of Set 4 | saquarema
# Processing Record 38 of Set 4 | mount gambier
# Processing Record 39 of Set 4 | ukrayinka
# Processing Record 40 of Set 4 | ife
# Processing Record 41 of Set 4 | caravelas
# Processing Record 42 of Set 4 | egvekinot
# Processing Record 43 of Set 4 | pontes e lacerda
# Processing Record 44 of Set 4 | birjand
# Processing Record 45 of Set 4 | east london
# Processing Record 46 of Set 4 | inuvik
# Processing Record 47 of Set 4 | zemio
# Processing Record 48 of Set 4 | keti bandar
# Processing Record 49 of Set 4 | sobolevo
# Processing Record 50 of Set 4 | kodiak
# Processing Record 1 of Set 5 | sayat
# Processing Record 2 of Set 5 | ardistan
# City not found. Skipping...
# Processing Record 3 of Set 5 | haradok
# Processing Record 4 of Set 5 | tigzirt
# Processing Record 5 of Set 5 | taoudenni
# Processing Record 6 of Set 5 | husavik
# Processing Record 7 of Set 5 | temaraia
# City not found. Skipping...
# Processing Record 8 of Set 5 | khorramshahr
# Processing Record 9 of Set 5 | makakilo city
# Processing Record 10 of Set 5 | pitimbu
# Processing Record 11 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 12 of Set 5 | puerto leguizamo
# Processing Record 13 of Set 5 | wainwright
# Processing Record 14 of Set 5 | fare
# Processing Record 15 of Set 5 | bucerias
# Processing Record 16 of Set 5 | torbay
# Processing Record 17 of Set 5 | te anau
# Processing Record 18 of Set 5 | severnyy-kospashskiy
# Processing Record 19 of Set 5 | nelson bay
# Processing Record 20 of Set 5 | lasem
# Processing Record 21 of Set 5 | multan
# Processing Record 22 of Set 5 | chateaubelair
# Processing Record 23 of Set 5 | yantongshan
# Processing Record 24 of Set 5 | syracuse
# Processing Record 25 of Set 5 | blagoyevo
# Processing Record 26 of Set 5 | half moon bay
# Processing Record 27 of Set 5 | salalah
# Processing Record 28 of Set 5 | yevlax
# Processing Record 29 of Set 5 | kahului
# Processing Record 30 of Set 5 | kidal
# Processing Record 31 of Set 5 | ostrovnoy
# Processing Record 32 of Set 5 | atar
# Processing Record 33 of Set 5 | gobabis
# Processing Record 34 of Set 5 | ribeira grande
# Processing Record 35 of Set 5 | zhangjiakou
# Processing Record 36 of Set 5 | albury
# Processing Record 37 of Set 5 | victoria
# Processing Record 38 of Set 5 | lermontovka
# Processing Record 39 of Set 5 | iznoski
# Processing Record 40 of Set 5 | sao gabriel da cachoeira
# Processing Record 41 of Set 5 | katha
# City not found. Skipping...
# Processing Record 42 of Set 5 | vyartsilya
# Processing Record 43 of Set 5 | agadez
# Processing Record 44 of Set 5 | srednekolymsk
# Processing Record 45 of Set 5 | peruibe
# Processing Record 46 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 47 of Set 5 | bubaque
# Processing Record 48 of Set 5 | katsuura
# Processing Record 49 of Set 5 | kamenka
# Processing Record 50 of Set 5 | mount isa
# Processing Record 1 of Set 6 | poya
# Processing Record 2 of Set 6 | vila franca do campo
# Processing Record 3 of Set 6 | general roca
# Processing Record 4 of Set 6 | nouadhibou
# Processing Record 5 of Set 6 | jalu
# Processing Record 6 of Set 6 | byron bay
# Processing Record 7 of Set 6 | pisco
# Processing Record 8 of Set 6 | kedrovyy
# Processing Record 9 of Set 6 | jardim
# Processing Record 10 of Set 6 | fonte boa
# Processing Record 11 of Set 6 | ilulissat
# Processing Record 12 of Set 6 | emirdag
# Processing Record 13 of Set 6 | namibe
# Processing Record 14 of Set 6 | youkounkoun
# Processing Record 15 of Set 6 | shelburne
# Processing Record 16 of Set 6 | guerrero negro
# Processing Record 17 of Set 6 | heishan
# Processing Record 18 of Set 6 | mayo
# Processing Record 19 of Set 6 | constitucion
# Processing Record 20 of Set 6 | ca mau
# Processing Record 21 of Set 6 | anloga
# Processing Record 22 of Set 6 | lagoa
# Processing Record 23 of Set 6 | faya
# Processing Record 24 of Set 6 | pervomayskoye
# Processing Record 25 of Set 6 | san patricio
# Processing Record 26 of Set 6 | cherskiy
# Processing Record 27 of Set 6 | barentu
# Processing Record 28 of Set 6 | masallatah
# Processing Record 29 of Set 6 | eldikan
# City not found. Skipping...
# Processing Record 30 of Set 6 | dondo
# Processing Record 31 of Set 6 | esperance
# Processing Record 32 of Set 6 | nyurba
# Processing Record 33 of Set 6 | sandpoint
# Processing Record 34 of Set 6 | yar-sale
# Processing Record 35 of Set 6 | mitsamiouli
# Processing Record 36 of Set 6 | chokurdakh
# Processing Record 37 of Set 6 | yining
# Processing Record 38 of Set 6 | dugna
# City not found. Skipping...
# Processing Record 39 of Set 6 | port hardy
# Processing Record 40 of Set 6 | gigmoto
# Processing Record 41 of Set 6 | shchebetovka
# Processing Record 42 of Set 6 | boa vista
# Processing Record 43 of Set 6 | chlorakas
# Processing Record 44 of Set 6 | port blair
# Processing Record 45 of Set 6 | roald
# Processing Record 46 of Set 6 | gewane
# Processing Record 47 of Set 6 | moose jaw
# Processing Record 48 of Set 6 | ponta do sol
# Processing Record 49 of Set 6 | rio grande
# Processing Record 50 of Set 6 | nizhniy kuranakh
# Processing Record 1 of Set 7 | cayenne
# Processing Record 2 of Set 7 | grand baie
# Processing Record 3 of Set 7 | mayya
# Processing Record 4 of Set 7 | kalakamati
# Processing Record 5 of Set 7 | cockburn town
# Processing Record 6 of Set 7 | davila
# Processing Record 7 of Set 7 | tabou
# Processing Record 8 of Set 7 | wahiawa
# Processing Record 9 of Set 7 | sao filipe
# Processing Record 10 of Set 7 | ayan
# Processing Record 11 of Set 7 | miri
# Processing Record 12 of Set 7 | brigantine
# Processing Record 13 of Set 7 | iqaluit
# Processing Record 14 of Set 7 | sorland
# Processing Record 15 of Set 7 | evensk
# Processing Record 16 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 17 of Set 7 | zyryanka
# Processing Record 18 of Set 7 | vila velha
# Processing Record 19 of Set 7 | baran
# Processing Record 20 of Set 7 | bismarck
# Processing Record 21 of Set 7 | sechura
# Processing Record 22 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 23 of Set 7 | ambilobe
# Processing Record 24 of Set 7 | mnogovershinnyy
# Processing Record 25 of Set 7 | fairbanks
# Processing Record 26 of Set 7 | tambacounda
# Processing Record 27 of Set 7 | akureyri
# Processing Record 28 of Set 7 | terekli-mekteb
# Processing Record 29 of Set 7 | codrington
# Processing Record 30 of Set 7 | manali
# Processing Record 31 of Set 7 | itoman
# Processing Record 32 of Set 7 | kargil
# Processing Record 33 of Set 7 | dunedin
# Processing Record 34 of Set 7 | mongoumba
# Processing Record 35 of Set 7 | karakol
# Processing Record 36 of Set 7 | ntungamo
# Processing Record 37 of Set 7 | gaurnadi
# Processing Record 38 of Set 7 | sarakhs
# Processing Record 39 of Set 7 | chopda
# Processing Record 40 of Set 7 | danshui
# Processing Record 41 of Set 7 | eydhafushi
# Processing Record 42 of Set 7 | elliot
# Processing Record 43 of Set 7 | nantucket
# Processing Record 44 of Set 7 | shimoda
# Processing Record 45 of Set 7 | praia da vitoria
# Processing Record 46 of Set 7 | mirina
# City not found. Skipping...
# Processing Record 47 of Set 7 | rovaniemi
# Processing Record 48 of Set 7 | geraldton
# Processing Record 49 of Set 7 | santo anastacio
# Processing Record 50 of Set 7 | la romana
# Processing Record 1 of Set 8 | srostki
# Processing Record 2 of Set 8 | rjukan
# Processing Record 3 of Set 8 | khandyga
# Processing Record 4 of Set 8 | auki
# Processing Record 5 of Set 8 | leglise
# Processing Record 6 of Set 8 | villefranche-de-rouergue
# Processing Record 7 of Set 8 | rosita
# Processing Record 8 of Set 8 | mankono
# Processing Record 9 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 10 of Set 8 | mildura
# Processing Record 11 of Set 8 | bonthe
# Processing Record 12 of Set 8 | huangchuan
# Processing Record 13 of Set 8 | trairi
# Processing Record 14 of Set 8 | singapore
# Processing Record 15 of Set 8 | kasongo-lunda
# Processing Record 16 of Set 8 | horlivka
# Processing Record 17 of Set 8 | svetlyy
# Processing Record 18 of Set 8 | saint-pierre
# Processing Record 19 of Set 8 | saint-augustin
# Processing Record 20 of Set 8 | jinchengjiang
# City not found. Skipping...
# Processing Record 21 of Set 8 | meulaboh
# Processing Record 22 of Set 8 | port-de-paix
# City not found. Skipping...
# Processing Record 23 of Set 8 | pance
# Processing Record 24 of Set 8 | upernavik
# Processing Record 25 of Set 8 | quatre cocos
# Processing Record 26 of Set 8 | nadym
# Processing Record 27 of Set 8 | tagusao
# Processing Record 28 of Set 8 | chapais
# Processing Record 29 of Set 8 | nalut
# Processing Record 30 of Set 8 | saint-louis
# Processing Record 31 of Set 8 | luena
# Processing Record 32 of Set 8 | tocopilla
# Processing Record 33 of Set 8 | namatanai
# Processing Record 34 of Set 8 | belushya guba
# City not found. Skipping...
# Processing Record 35 of Set 8 | ipixuna
# Processing Record 36 of Set 8 | ishigaki
# Processing Record 37 of Set 8 | nanortalik
# Processing Record 38 of Set 8 | kijang
# Processing Record 39 of Set 8 | inirida
# Processing Record 40 of Set 8 | mbaiki
# Processing Record 41 of Set 8 | kondinskoye
# Processing Record 42 of Set 8 | salinopolis
# Processing Record 43 of Set 8 | lata
# Processing Record 44 of Set 8 | san pedro
# Processing Record 45 of Set 8 | rosario
# Processing Record 46 of Set 8 | turayf
# Processing Record 47 of Set 8 | vestmannaeyjar
# Processing Record 48 of Set 8 | marsa matruh
# Processing Record 49 of Set 8 | kaffrine
# Processing Record 50 of Set 8 | yulara
# Processing Record 1 of Set 9 | sevierville
# Processing Record 2 of Set 9 | saint andrews
# Processing Record 3 of Set 9 | kundarki
# City not found. Skipping...
# Processing Record 4 of Set 9 | kviteseid
# Processing Record 5 of Set 9 | aleksandrovka
# Processing Record 6 of Set 9 | cabo rojo
# Processing Record 7 of Set 9 | anito
# Processing Record 8 of Set 9 | coquimbo
# Processing Record 9 of Set 9 | maldonado
# Processing Record 10 of Set 9 | orlik
# Processing Record 11 of Set 9 | buqayq
# City not found. Skipping...
# Processing Record 12 of Set 9 | kurumkan
# Processing Record 13 of Set 9 | puerto escondido
# Processing Record 14 of Set 9 | guelph
# Processing Record 15 of Set 9 | hopelchen
# Processing Record 16 of Set 9 | melong
# Processing Record 17 of Set 9 | mountain home
# Processing Record 18 of Set 9 | asfi
# Processing Record 19 of Set 9 | tokmak
# Processing Record 20 of Set 9 | olafsvik
# Processing Record 21 of Set 9 | jinchang
# Processing Record 22 of Set 9 | anadyr
# Processing Record 23 of Set 9 | svetlaya
# Processing Record 24 of Set 9 | salvador
# Processing Record 25 of Set 9 | beringovskiy
# Processing Record 26 of Set 9 | santo nino
# Processing Record 27 of Set 9 | portland
# Processing Record 28 of Set 9 | roros
# Processing Record 29 of Set 9 | bima
# Processing Record 30 of Set 9 | muzhi
# Processing Record 31 of Set 9 | ust-nera
# Processing Record 32 of Set 9 | longyearbyen
# Processing Record 33 of Set 9 | kavieng
# Processing Record 34 of Set 9 | marawi
# Processing Record 35 of Set 9 | sao joao da barra
# Processing Record 36 of Set 9 | mori
# Processing Record 37 of Set 9 | hihifo
# City not found. Skipping...
# Processing Record 38 of Set 9 | cururupu
# Processing Record 39 of Set 9 | chor
# Processing Record 40 of Set 9 | farmington
# Processing Record 41 of Set 9 | bayeux
# Processing Record 42 of Set 9 | collie
# Processing Record 43 of Set 9 | mackenzie
# Processing Record 44 of Set 9 | coihaique
# Processing Record 45 of Set 9 | hasaki
# Processing Record 46 of Set 9 | maicao
# Processing Record 47 of Set 9 | banda aceh
# Processing Record 48 of Set 9 | xinmin
# Processing Record 49 of Set 9 | lorengau
# Processing Record 50 of Set 9 | cap-aux-meules
# Processing Record 1 of Set 10 | yumen
# Processing Record 2 of Set 10 | omboue
# Processing Record 3 of Set 10 | souillac
# Processing Record 4 of Set 10 | inzer
# Processing Record 5 of Set 10 | pahrump
# Processing Record 6 of Set 10 | fairmont
# Processing Record 7 of Set 10 | xadani
# City not found. Skipping...
# Processing Record 8 of Set 10 | lashio
# Processing Record 9 of Set 10 | kalanguy
# Processing Record 10 of Set 10 | bandarbeyla
# Processing Record 11 of Set 10 | san jose
# Processing Record 12 of Set 10 | krasnoselkup
# Processing Record 13 of Set 10 | gorontalo
# Processing Record 14 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 15 of Set 10 | quang ngai
# Processing Record 16 of Set 10 | baykit
# Processing Record 17 of Set 10 | blythe
# Processing Record 18 of Set 10 | mecca
# Processing Record 19 of Set 10 | noumea
# Processing Record 20 of Set 10 | rawson
# Processing Record 21 of Set 10 | saint-joseph
# Processing Record 22 of Set 10 | carballo
# Processing Record 23 of Set 10 | gunjur
# Processing Record 24 of Set 10 | stekolnyy
# City not found. Skipping...
# Processing Record 25 of Set 10 | narsaq
# Processing Record 26 of Set 10 | kumluca
# Processing Record 27 of Set 10 | buritis
# Processing Record 28 of Set 10 | mumbwa
# Processing Record 29 of Set 10 | valparaiso
# Processing Record 30 of Set 10 | mugur-aksy
# Processing Record 31 of Set 10 | sterling
# Processing Record 32 of Set 10 | aklavik
# Processing Record 33 of Set 10 | igarka
# Processing Record 34 of Set 10 | port hawkesbury
# Processing Record 35 of Set 10 | tecoanapa
# Processing Record 36 of Set 10 | canandaigua
# Processing Record 37 of Set 10 | pangnirtung
# Processing Record 38 of Set 10 | doha
# Processing Record 39 of Set 10 | ndele
# Processing Record 40 of Set 10 | northam
# Processing Record 41 of Set 10 | inveraray
# City not found. Skipping...
# Processing Record 42 of Set 10 | cabo san lucas
# Processing Record 43 of Set 10 | san giustino
# Processing Record 44 of Set 10 | nichinan
# Processing Record 45 of Set 10 | bartica
# Processing Record 46 of Set 10 | caxito
# Processing Record 47 of Set 10 | conceicao do mato dentro
# Processing Record 48 of Set 10 | tarko-sale
# Processing Record 49 of Set 10 | atherton
# Processing Record 50 of Set 10 | iracoubo
# Processing Record 1 of Set 11 | plettenberg bay
# Processing Record 2 of Set 11 | manokwari
# Processing Record 3 of Set 11 | ulagan
# Processing Record 4 of Set 11 | takoradi
# Processing Record 5 of Set 11 | wicklow
# Processing Record 6 of Set 11 | flin flon
# Processing Record 7 of Set 11 | jinka
# Processing Record 8 of Set 11 | kieta
# Processing Record 9 of Set 11 | alice springs
# Processing Record 10 of Set 11 | sangre grande
# Processing Record 11 of Set 11 | novoagansk
# Processing Record 12 of Set 11 | mareeba
# Processing Record 13 of Set 11 | arawa
# Processing Record 14 of Set 11 | ketchikan
# Processing Record 15 of Set 11 | huilong
# Processing Record 16 of Set 11 | cumaribo
# City not found. Skipping...
# Processing Record 17 of Set 11 | kupang
# Processing Record 18 of Set 11 | shimoni
# Processing Record 19 of Set 11 | hukuntsi
# Processing Record 20 of Set 11 | vilaka
# Processing Record 21 of Set 11 | yuncheng
# Processing Record 22 of Set 11 | hamilton
# Processing Record 23 of Set 11 | fillan
# Processing Record 24 of Set 11 | fort-shevchenko
# Processing Record 25 of Set 11 | marapanim
# Processing Record 26 of Set 11 | labrea
# Processing Record 27 of Set 11 | dzilam gonzalez
# Processing Record 28 of Set 11 | kaeo
# Processing Record 29 of Set 11 | abrau-dyurso
# Processing Record 30 of Set 11 | mbanza-ngungu
# Processing Record 31 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 32 of Set 11 | broken hill
# Processing Record 33 of Set 11 | ponta delgada
# Processing Record 34 of Set 11 | orchard homes
# Processing Record 35 of Set 11 | la palma
# Processing Record 36 of Set 11 | gravdal
# Processing Record 37 of Set 11 | petauke
# Processing Record 38 of Set 11 | maningrida
# Processing Record 39 of Set 11 | grindavik
# Processing Record 40 of Set 11 | artyk
# City not found. Skipping...
# Processing Record 41 of Set 11 | arlit
# Processing Record 42 of Set 11 | nurlat
# Processing Record 43 of Set 11 | oranjemund
# Processing Record 44 of Set 11 | borlange
# City not found. Skipping...
# Processing Record 45 of Set 11 | san rafael
# Processing Record 46 of Set 11 | skibbereen
# Processing Record 47 of Set 11 | sangar
# Processing Record 48 of Set 11 | gouyave
# Processing Record 49 of Set 11 | sillamae
# Processing Record 50 of Set 11 | berbera
# Processing Record 1 of Set 12 | peniche
# Processing Record 2 of Set 12 | sioux lookout
# Processing Record 3 of Set 12 | cabra
# Processing Record 4 of Set 12 | bathsheba
# Processing Record 5 of Set 12 | ahipara
# Processing Record 6 of Set 12 | goodlettsville
# Processing Record 7 of Set 12 | ixtapa
# Processing Record 8 of Set 12 | neiafu
# Processing Record 9 of Set 12 | vaitupu
# City not found. Skipping...
# Processing Record 10 of Set 12 | leopold
# Processing Record 11 of Set 12 | deer lake
# Processing Record 12 of Set 12 | sao raimundo das mangabeiras
# Processing Record 13 of Set 12 | richards bay
# Processing Record 14 of Set 12 | fuerte olimpo
# Processing Record 15 of Set 12 | hasanabad
# Processing Record 16 of Set 12 | oussouye
# Processing Record 17 of Set 12 | sur
# Processing Record 18 of Set 12 | belmonte
# Processing Record 19 of Set 12 | qaqortoq
# Processing Record 20 of Set 12 | ondjiva
# Processing Record 21 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 22 of Set 12 | zovaber
# Processing Record 23 of Set 12 | changji
# Processing Record 24 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 25 of Set 12 | urdoma
# Processing Record 26 of Set 12 | maragogi
# Processing Record 27 of Set 12 | ryotsu
# Processing Record 28 of Set 12 | ola
# Processing Record 29 of Set 12 | ous
# Processing Record 30 of Set 12 | sola
# Processing Record 31 of Set 12 | buala
# Processing Record 32 of Set 12 | riachao das neves
# Processing Record 33 of Set 12 | kloulklubed
# Processing Record 34 of Set 12 | huarmey
# Processing Record 35 of Set 12 | edson
# Processing Record 36 of Set 12 | talara
# Processing Record 37 of Set 12 | kilindoni
# Processing Record 38 of Set 12 | arman
# Processing Record 39 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 40 of Set 12 | winnemucca
# Processing Record 41 of Set 12 | mokhsogollokh
# Processing Record 42 of Set 12 | lufilufi
# Processing Record 43 of Set 12 | constantine
# Processing Record 44 of Set 12 | paciran
# Processing Record 45 of Set 12 | kailua
# Processing Record 46 of Set 12 | along
# Processing Record 47 of Set 12 | ust-maya
# Processing Record 48 of Set 12 | verkhnyaya inta
# Processing Record 49 of Set 12 | rock springs
# Processing Record 50 of Set 12 | abashiri
# Processing Record 1 of Set 13 | waycross
# Processing Record 2 of Set 13 | tura
# Processing Record 3 of Set 13 | olinda
# Processing Record 4 of Set 13 | panjwin
# City not found. Skipping...
# Processing Record 5 of Set 13 | santiago del estero
# Processing Record 6 of Set 13 | la ronge
# Processing Record 7 of Set 13 | qeshm
# Processing Record 8 of Set 13 | paucartambo
# City not found. Skipping...
# Processing Record 9 of Set 13 | tazovskiy
# Processing Record 10 of Set 13 | mandalgovi
# Processing Record 11 of Set 13 | qandala
# Processing Record 12 of Set 13 | naze
# Processing Record 13 of Set 13 | patuli
# Processing Record 14 of Set 13 | aix-les-bains
# Processing Record 15 of Set 13 | saint anthony
# Processing Record 16 of Set 13 | kilosa
# Processing Record 17 of Set 13 | anar darreh
# City not found. Skipping...
# Processing Record 18 of Set 13 | nuevo casas grandes
# Processing Record 19 of Set 13 | sumedang
# Processing Record 20 of Set 13 | lethem
# Processing Record 21 of Set 13 | grand gaube
# Processing Record 22 of Set 13 | yarada
# Processing Record 23 of Set 13 | daytona beach
# Processing Record 24 of Set 13 | mamallapuram
# Processing Record 25 of Set 13 | porosozero
# Processing Record 26 of Set 13 | gazli
# Processing Record 27 of Set 13 | los llanos de aridane
# Processing Record 28 of Set 13 | dhidhdhoo
# Processing Record 29 of Set 13 | jian
# Processing Record 30 of Set 13 | sept-iles
# Processing Record 31 of Set 13 | qazvin
# Processing Record 32 of Set 13 | bacolod
# Processing Record 33 of Set 13 | hunza
# City not found. Skipping...
# Processing Record 34 of Set 13 | bababe
# City not found. Skipping...
# Processing Record 35 of Set 13 | trinidad
# Processing Record 36 of Set 13 | illela
# Processing Record 37 of Set 13 | yantal
# Processing Record 38 of Set 13 | zabol
# Processing Record 39 of Set 13 | talnakh
# Processing Record 40 of Set 13 | robore
# Processing Record 41 of Set 13 | plonsk
# Processing Record 42 of Set 13 | barbar
# City not found. Skipping...
# Processing Record 43 of Set 13 | fiche
# Processing Record 44 of Set 13 | saint cloud
# Processing Record 45 of Set 13 | abbotsford
# Processing Record 46 of Set 13 | riverton
# Processing Record 47 of Set 13 | tongliao
# Processing Record 48 of Set 13 | severo-yeniseyskiy
# Processing Record 49 of Set 13 | mosquera
# Processing Record 50 of Set 13 | makinsk
# Processing Record 1 of Set 14 | bukachacha
# Processing Record 2 of Set 14 | peace river
# Processing Record 3 of Set 14 | kamariotissa
# Processing Record 4 of Set 14 | maceio
# Processing Record 5 of Set 14 | jizan
# Processing Record 6 of Set 14 | robat karim
# Processing Record 7 of Set 14 | male
# Processing Record 8 of Set 14 | koyilandi
# City not found. Skipping...
# Processing Record 9 of Set 14 | marcona
# City not found. Skipping...
# Processing Record 10 of Set 14 | lodja
# Processing Record 11 of Set 14 | esterhazy
# Processing Record 12 of Set 14 | tromso
# Processing Record 13 of Set 14 | cikupa
# Processing Record 14 of Set 14 | franca
# Processing Record 15 of Set 14 | canutama
# Processing Record 16 of Set 14 | sitka
# Processing Record 17 of Set 14 | andenes
# Processing Record 18 of Set 14 | monrovia
# Processing Record 19 of Set 14 | emerald
# Processing Record 20 of Set 14 | bilibino
# Processing Record 21 of Set 14 | bandiagara
# Processing Record 22 of Set 14 | mana
# Processing Record 23 of Set 14 | longlac
# City not found. Skipping...
# Processing Record 24 of Set 14 | san andres
# Processing Record 25 of Set 14 | russell
# Processing Record 26 of Set 14 | ilhabela
# Processing Record 27 of Set 14 | haines junction
# Processing Record 28 of Set 14 | prince rupert
# Processing Record 29 of Set 14 | marsh harbour
# Processing Record 30 of Set 14 | chany
# Processing Record 31 of Set 14 | srivardhan
# Processing Record 32 of Set 14 | ussel
# Processing Record 33 of Set 14 | tchollire
# Processing Record 34 of Set 14 | porto novo
# Processing Record 35 of Set 14 | baryshivka
# Processing Record 36 of Set 14 | sayyan
# Processing Record 37 of Set 14 | ngaoundere
# Processing Record 38 of Set 14 | jahrom
# City not found. Skipping...
# Processing Record 39 of Set 14 | monterey
# Processing Record 40 of Set 14 | hualmay
# Processing Record 41 of Set 14 | rapid valley
# Processing Record 42 of Set 14 | havre-saint-pierre
# Processing Record 43 of Set 14 | aginskoye
# Processing Record 44 of Set 14 | kalmunai
# Processing Record 45 of Set 14 | kachikau
# City not found. Skipping...
# Processing Record 46 of Set 14 | ko samui
# Processing Record 47 of Set 14 | altayskoye
# Processing Record 48 of Set 14 | ravar
# Processing Record 49 of Set 14 | verkhnevilyuysk
# Processing Record 50 of Set 14 | lastoursville
# Processing Record 1 of Set 15 | iranshahr
# Processing Record 2 of Set 15 | port keats
# Processing Record 3 of Set 15 | yanam
# Processing Record 4 of Set 15 | innisfail
# Processing Record 5 of Set 15 | vadso
# Processing Record 6 of Set 15 | meadow lake
# Processing Record 7 of Set 15 | jiuquan
# Processing Record 8 of Set 15 | boudry
# Processing Record 9 of Set 15 | chaozhou
# Processing Record 10 of Set 15 | maroantsetra
# Processing Record 11 of Set 15 | nishihara
# Processing Record 12 of Set 15 | marzuq
# Processing Record 13 of Set 15 | strezhevoy
# Processing Record 14 of Set 15 | envira
# Processing Record 15 of Set 15 | north bend
# Processing Record 16 of Set 15 | mahajanga
# Processing Record 17 of Set 15 | kysyl-syr
# Processing Record 18 of Set 15 | sampit
# Processing Record 19 of Set 15 | marinette
# Processing Record 20 of Set 15 | amahai
# Processing Record 21 of Set 15 | horasan
# Processing Record 22 of Set 15 | aswan
# Processing Record 23 of Set 15 | korla
# Processing Record 24 of Set 15 | komsomolskiy
# Processing Record 25 of Set 15 | balotra
# Processing Record 26 of Set 15 | langsa
# Processing Record 27 of Set 15 | veraval
# Processing Record 28 of Set 15 | ruteng
# Processing Record 29 of Set 15 | santa maria
# Processing Record 30 of Set 15 | isabela
# Processing Record 31 of Set 15 | harpanahalli
# Processing Record 32 of Set 15 | ozernovskiy
# Processing Record 33 of Set 15 | limbazi
# Processing Record 34 of Set 15 | nieuw amsterdam
# Processing Record 35 of Set 15 | baherden
# Processing Record 36 of Set 15 | carahue
# Processing Record 37 of Set 15 | salamanca
# Processing Record 38 of Set 15 | orumiyeh
# Processing Record 39 of Set 15 | the valley
# Processing Record 40 of Set 15 | stornoway
# Processing Record 41 of Set 15 | port macquarie
# Processing Record 42 of Set 15 | kargasok
# Processing Record 43 of Set 15 | sayanogorsk
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
length_data = (len(city_data))
length_data
# Out:
# 686

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Kaitangata      NZ -46.2817  169.8464     52.16        96          79
# 1       Rikitea      PF -23.1203 -134.9692     76.82        74          16
# 2        Orthez      FR  43.4884   -0.7724     58.75        75           0
# 3         Kenai      US  60.5544 -151.2583      8.65        56         100
# 4       Ushuaia      AR -54.8000  -68.3000     58.66        55          40
# 5       Qaanaaq      GL  77.4840  -69.3632    -16.67        67          82
# 6  Saint George      US  37.1041 -113.5841     49.42        48           0
# 7         Zalha      RO  47.1833   23.5333     37.58        96         100
# 8     Busselton      AU -33.6500  115.3333     60.13        93          44
# 9      Sisimiut      GL  66.9395  -53.6735      7.68        59          16
#
#    Wind Speed Current Description                 Date
# 0        2.39       broken clouds  2022-12-24 18:27:46
# 1       10.71          light rain  2022-12-24 18:23:43
# 2        5.23           clear sky  2022-12-24 18:33:36
# 3       14.97     overcast clouds  2022-12-24 18:33:36
# 4       29.93    scattered clouds  2022-12-24 18:23:55
# 5        5.75       broken clouds  2022-12-24 18:25:18
# 6        1.01           clear sky  2022-12-24 18:29:28
# 7        5.26     overcast clouds  2022-12-24 18:33:37
# 8        9.24    scattered clouds  2022-12-24 18:26:32
# 9       12.10          few clouds  2022-12-24 18:33:38

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description', 'Date'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]
# Display sample data
city_data_df.head(10)
# Out:
#            City Country                 Date      Lat       Lng  Max Temp  \
# 0    Kaitangata      NZ  2022-12-24 18:27:46 -46.2817  169.8464     52.16
# 1       Rikitea      PF  2022-12-24 18:23:43 -23.1203 -134.9692     76.82
# 2        Orthez      FR  2022-12-24 18:33:36  43.4884   -0.7724     58.75
# 3         Kenai      US  2022-12-24 18:33:36  60.5544 -151.2583      8.65
# 4       Ushuaia      AR  2022-12-24 18:23:55 -54.8000  -68.3000     58.66
# 5       Qaanaaq      GL  2022-12-24 18:25:18  77.4840  -69.3632    -16.67
# 6  Saint George      US  2022-12-24 18:29:28  37.1041 -113.5841     49.42
# 7         Zalha      RO  2022-12-24 18:33:37  47.1833   23.5333     37.58
# 8     Busselton      AU  2022-12-24 18:26:32 -33.6500  115.3333     60.13
# 9      Sisimiut      GL  2022-12-24 18:33:38  66.9395  -53.6735      7.68
#
#    Humidity  Cloudiness  Wind Speed
# 0        96          79        2.39
# 1        74          16       10.71
# 2        75           0        5.23
# 3        56         100       14.97
# 4        55          40       29.93
# 5        67          82        5.75
# 6        48           0        1.01
# 7        96         100        5.26
# 8        93          44        9.24
# 9        59          16       12.10

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City           object
# Country        object
# Date           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "Weather_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
