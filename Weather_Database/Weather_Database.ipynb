# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from citipy import citipy
from config import weather_api_key

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 768

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        current_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":current_description,
                          "Date": city_date})
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | castro
# Processing Record 2 of Set 1 | mar del plata
# Processing Record 3 of Set 1 | turukhansk
# Processing Record 4 of Set 1 | mandali
# Processing Record 5 of Set 1 | punta arenas
# Processing Record 6 of Set 1 | busselton
# Processing Record 7 of Set 1 | nikolskoye
# Processing Record 8 of Set 1 | hermanus
# Processing Record 9 of Set 1 | provideniya
# Processing Record 10 of Set 1 | solovetskiy
# City not found. Skipping...
# Processing Record 11 of Set 1 | roanoke rapids
# Processing Record 12 of Set 1 | bredasdorp
# Processing Record 13 of Set 1 | podor
# Processing Record 14 of Set 1 | mataura
# Processing Record 15 of Set 1 | sanandaj
# Processing Record 16 of Set 1 | moram
# Processing Record 17 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 18 of Set 1 | port elizabeth
# Processing Record 19 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 20 of Set 1 | ushuaia
# Processing Record 21 of Set 1 | garmsar
# Processing Record 22 of Set 1 | pisco
# Processing Record 23 of Set 1 | bluff
# Processing Record 24 of Set 1 | shetpe
# Processing Record 25 of Set 1 | thompson
# Processing Record 26 of Set 1 | aspindza
# Processing Record 27 of Set 1 | arraial do cabo
# Processing Record 28 of Set 1 | hami
# Processing Record 29 of Set 1 | jamestown
# Processing Record 30 of Set 1 | sao filipe
# Processing Record 31 of Set 1 | manzhouli
# Processing Record 32 of Set 1 | shima
# Processing Record 33 of Set 1 | kathu
# Processing Record 34 of Set 1 | hithadhoo
# Processing Record 35 of Set 1 | sohag
# Processing Record 36 of Set 1 | vanimo
# Processing Record 37 of Set 1 | auki
# Processing Record 38 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 39 of Set 1 | balabagan
# Processing Record 40 of Set 1 | vaini
# Processing Record 41 of Set 1 | zambezi
# Processing Record 42 of Set 1 | saint george
# Processing Record 43 of Set 1 | nishihara
# Processing Record 44 of Set 1 | dikson
# Processing Record 45 of Set 1 | hobart
# Processing Record 46 of Set 1 | san quintin
# Processing Record 47 of Set 1 | cape town
# Processing Record 48 of Set 1 | grindavik
# Processing Record 49 of Set 1 | port lincoln
# Processing Record 50 of Set 1 | vranov
# Processing Record 1 of Set 2 | chokurdakh
# Processing Record 2 of Set 2 | sebinkarahisar
# Processing Record 3 of Set 2 | grand-lahou
# Processing Record 4 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 2 | kodiak
# Processing Record 6 of Set 2 | mayo
# Processing Record 7 of Set 2 | albany
# Processing Record 8 of Set 2 | karasjok
# Processing Record 9 of Set 2 | qaanaaq
# Processing Record 10 of Set 2 | khatanga
# Processing Record 11 of Set 2 | kloulklubed
# Processing Record 12 of Set 2 | pangody
# Processing Record 13 of Set 2 | poum
# Processing Record 14 of Set 2 | bengkulu
# Processing Record 15 of Set 2 | puerto ayora
# Processing Record 16 of Set 2 | east london
# Processing Record 17 of Set 2 | port blair
# Processing Record 18 of Set 2 | egvekinot
# Processing Record 19 of Set 2 | rikitea
# Processing Record 20 of Set 2 | le port
# Processing Record 21 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 22 of Set 2 | nantucket
# Processing Record 23 of Set 2 | klaksvik
# Processing Record 24 of Set 2 | pevek
# Processing Record 25 of Set 2 | ferrol
# Processing Record 26 of Set 2 | whitehorse
# Processing Record 27 of Set 2 | yellowknife
# Processing Record 28 of Set 2 | nouadhibou
# Processing Record 29 of Set 2 | sorland
# Processing Record 30 of Set 2 | kapaa
# Processing Record 31 of Set 2 | skalistyy
# City not found. Skipping...
# Processing Record 32 of Set 2 | coihaique
# Processing Record 33 of Set 2 | aykhal
# Processing Record 34 of Set 2 | kaitangata
# Processing Record 35 of Set 2 | turner
# Processing Record 36 of Set 2 | makakilo city
# Processing Record 37 of Set 2 | barrow
# Processing Record 38 of Set 2 | lompoc
# Processing Record 39 of Set 2 | maningrida
# Processing Record 40 of Set 2 | mahebourg
# Processing Record 41 of Set 2 | malibu
# Processing Record 42 of Set 2 | padang
# Processing Record 43 of Set 2 | birin
# Processing Record 44 of Set 2 | prainha
# Processing Record 45 of Set 2 | tuktoyaktuk
# Processing Record 46 of Set 2 | los algarrobos
# Processing Record 47 of Set 2 | tabas
# Processing Record 48 of Set 2 | rolim de moura
# City not found. Skipping...
# Processing Record 49 of Set 2 | torgau
# Processing Record 50 of Set 2 | skibbereen
# Processing Record 1 of Set 3 | mae hong son
# Processing Record 2 of Set 3 | tasiilaq
# Processing Record 3 of Set 3 | oksfjord
# Processing Record 4 of Set 3 | goderich
# Processing Record 5 of Set 3 | ponta do sol
# Processing Record 6 of Set 3 | sur
# Processing Record 7 of Set 3 | oktyabrskoye
# Processing Record 8 of Set 3 | new norfolk
# Processing Record 9 of Set 3 | hambantota
# Processing Record 10 of Set 3 | clyde river
# Processing Record 11 of Set 3 | dudinka
# Processing Record 12 of Set 3 | atuona
# Processing Record 13 of Set 3 | cayenne
# Processing Record 14 of Set 3 | port shepstone
# Processing Record 15 of Set 3 | narsaq
# Processing Record 16 of Set 3 | kirkwall
# Processing Record 17 of Set 3 | butaritari
# Processing Record 18 of Set 3 | beroroha
# Processing Record 19 of Set 3 | nadym
# Processing Record 20 of Set 3 | hilo
# Processing Record 21 of Set 3 | mbekenyera
# Processing Record 22 of Set 3 | ahipara
# Processing Record 23 of Set 3 | grand forks
# Processing Record 24 of Set 3 | komsomolskiy
# Processing Record 25 of Set 3 | porto velho
# Processing Record 26 of Set 3 | jalu
# Processing Record 27 of Set 3 | ancud
# Processing Record 28 of Set 3 | bataipora
# Processing Record 29 of Set 3 | torbay
# Processing Record 30 of Set 3 | tagusao
# Processing Record 31 of Set 3 | saint-philippe
# Processing Record 32 of Set 3 | ribeira grande
# Processing Record 33 of Set 3 | caiaponia
# Processing Record 34 of Set 3 | tuatapere
# Processing Record 35 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 36 of Set 3 | khilok
# Processing Record 37 of Set 3 | iringa
# Processing Record 38 of Set 3 | bonavista
# Processing Record 39 of Set 3 | dunedin
# Processing Record 40 of Set 3 | yulara
# Processing Record 41 of Set 3 | varhaug
# Processing Record 42 of Set 3 | bonthe
# Processing Record 43 of Set 3 | avarua
# Processing Record 44 of Set 3 | matagami
# Processing Record 45 of Set 3 | quatre cocos
# Processing Record 46 of Set 3 | tigil
# Processing Record 47 of Set 3 | lensk
# Processing Record 48 of Set 3 | evensk
# Processing Record 49 of Set 3 | kazminskoye
# City not found. Skipping...
# Processing Record 50 of Set 3 | constitucion
# Processing Record 1 of Set 4 | la asuncion
# Processing Record 2 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 3 of Set 4 | polonnaruwa
# Processing Record 4 of Set 4 | katsuura
# Processing Record 5 of Set 4 | pangnirtung
# Processing Record 6 of Set 4 | kaeo
# Processing Record 7 of Set 4 | cidreira
# Processing Record 8 of Set 4 | kushima
# Processing Record 9 of Set 4 | lasa
# Processing Record 10 of Set 4 | borgarnes
# Processing Record 11 of Set 4 | avera
# Processing Record 12 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 13 of Set 4 | saskylakh
# Processing Record 14 of Set 4 | la orilla
# Processing Record 15 of Set 4 | belmonte
# Processing Record 16 of Set 4 | mattru
# Processing Record 17 of Set 4 | georgetown
# Processing Record 18 of Set 4 | alofi
# Processing Record 19 of Set 4 | half moon bay
# Processing Record 20 of Set 4 | san cristobal
# Processing Record 21 of Set 4 | sistranda
# Processing Record 22 of Set 4 | matara
# Processing Record 23 of Set 4 | souillac
# Processing Record 24 of Set 4 | qui nhon
# Processing Record 25 of Set 4 | vila velha
# Processing Record 26 of Set 4 | biak
# Processing Record 27 of Set 4 | waitati
# Processing Record 28 of Set 4 | san rafael
# Processing Record 29 of Set 4 | salalah
# Processing Record 30 of Set 4 | victoria
# Processing Record 31 of Set 4 | ranot
# Processing Record 32 of Set 4 | airai
# Processing Record 33 of Set 4 | port alfred
# Processing Record 34 of Set 4 | severo-kurilsk
# Processing Record 35 of Set 4 | mae chan
# Processing Record 36 of Set 4 | gurgan
# City not found. Skipping...
# Processing Record 37 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 38 of Set 4 | capitao poco
# Processing Record 39 of Set 4 | saint-raymond
# Processing Record 40 of Set 4 | lebu
# Processing Record 41 of Set 4 | kirakira
# Processing Record 42 of Set 4 | port augusta
# Processing Record 43 of Set 4 | meulaboh
# Processing Record 44 of Set 4 | sangmelima
# Processing Record 45 of Set 4 | geraldton
# Processing Record 46 of Set 4 | kavieng
# Processing Record 47 of Set 4 | yinchuan
# Processing Record 48 of Set 4 | rundu
# Processing Record 49 of Set 4 | kieta
# Processing Record 50 of Set 4 | tolbazy
# Processing Record 1 of Set 5 | novikovo
# Processing Record 2 of Set 5 | honiara
# Processing Record 3 of Set 5 | gobabis
# Processing Record 4 of Set 5 | katherine
# Processing Record 5 of Set 5 | bethel
# Processing Record 6 of Set 5 | emerald
# Processing Record 7 of Set 5 | phalaborwa
# Processing Record 8 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 9 of Set 5 | husavik
# Processing Record 10 of Set 5 | carnarvon
# Processing Record 11 of Set 5 | namibe
# Processing Record 12 of Set 5 | anadyr
# Processing Record 13 of Set 5 | ascension
# Processing Record 14 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 15 of Set 5 | pacific grove
# Processing Record 16 of Set 5 | gulmarg
# Processing Record 17 of Set 5 | ilulissat
# Processing Record 18 of Set 5 | batticaloa
# Processing Record 19 of Set 5 | puerto escondido
# Processing Record 20 of Set 5 | savelugu
# Processing Record 21 of Set 5 | muskegon heights
# Processing Record 22 of Set 5 | saint-augustin
# Processing Record 23 of Set 5 | caravelas
# Processing Record 24 of Set 5 | pemangkat
# Processing Record 25 of Set 5 | trairi
# Processing Record 26 of Set 5 | nanlong
# Processing Record 27 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 28 of Set 5 | batsfjord
# Processing Record 29 of Set 5 | luba
# Processing Record 30 of Set 5 | sitka
# Processing Record 31 of Set 5 | healdsburg
# Processing Record 32 of Set 5 | richards bay
# Processing Record 33 of Set 5 | nizhneshilovka
# City not found. Skipping...
# Processing Record 34 of Set 5 | jiddah
# City not found. Skipping...
# Processing Record 35 of Set 5 | codrington
# Processing Record 36 of Set 5 | bowral
# Processing Record 37 of Set 5 | litoral del san juan
# City not found. Skipping...
# Processing Record 38 of Set 5 | mokhsogollokh
# Processing Record 39 of Set 5 | komsomolskoye
# Processing Record 40 of Set 5 | hato mayor
# Processing Record 41 of Set 5 | arrecife
# Processing Record 42 of Set 5 | los llanos de aridane
# Processing Record 43 of Set 5 | la ronge
# Processing Record 44 of Set 5 | kencong
# Processing Record 45 of Set 5 | saint anthony
# Processing Record 46 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 47 of Set 5 | nueva loja
# Processing Record 48 of Set 5 | muskogee
# Processing Record 49 of Set 5 | kandrian
# Processing Record 50 of Set 5 | lima
# Processing Record 1 of Set 6 | varniai
# Processing Record 2 of Set 6 | kaniama
# Processing Record 3 of Set 6 | caucaia
# Processing Record 4 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 5 of Set 6 | chapayeve
# Processing Record 6 of Set 6 | altay
# Processing Record 7 of Set 6 | lorengau
# Processing Record 8 of Set 6 | pathein
# Processing Record 9 of Set 6 | szendro
# Processing Record 10 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 11 of Set 6 | sao joao da barra
# Processing Record 12 of Set 6 | bahia honda
# Processing Record 13 of Set 6 | ouallam
# Processing Record 14 of Set 6 | pahrump
# Processing Record 15 of Set 6 | kongolo
# Processing Record 16 of Set 6 | polunochnoye
# Processing Record 17 of Set 6 | dire
# Processing Record 18 of Set 6 | coquimbo
# Processing Record 19 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 20 of Set 6 | inegol
# Processing Record 21 of Set 6 | rio hato
# Processing Record 22 of Set 6 | esperance
# Processing Record 23 of Set 6 | kabinda
# Processing Record 24 of Set 6 | camacha
# Processing Record 25 of Set 6 | tocopilla
# Processing Record 26 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 27 of Set 6 | samarai
# Processing Record 28 of Set 6 | brumadinho
# Processing Record 29 of Set 6 | galgani
# City not found. Skipping...
# Processing Record 30 of Set 6 | kahului
# Processing Record 31 of Set 6 | leningradskiy
# Processing Record 32 of Set 6 | bandar
# Processing Record 33 of Set 6 | kautokeino
# Processing Record 34 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 35 of Set 6 | sao jose da coroa grande
# Processing Record 36 of Set 6 | kutum
# Processing Record 37 of Set 6 | nara
# Processing Record 38 of Set 6 | tailai
# Processing Record 39 of Set 6 | tual
# Processing Record 40 of Set 6 | port hardy
# Processing Record 41 of Set 6 | kununurra
# Processing Record 42 of Set 6 | awjilah
# Processing Record 43 of Set 6 | la paz
# Processing Record 44 of Set 6 | san patricio
# Processing Record 45 of Set 6 | adrar
# Processing Record 46 of Set 6 | baneh
# Processing Record 47 of Set 6 | sinnamary
# Processing Record 48 of Set 6 | montepuez
# Processing Record 49 of Set 6 | dingle
# Processing Record 50 of Set 6 | valparaiso
# Processing Record 1 of Set 7 | sambava
# Processing Record 2 of Set 7 | alice springs
# Processing Record 3 of Set 7 | almaznyy
# Processing Record 4 of Set 7 | sampit
# Processing Record 5 of Set 7 | tiksi
# Processing Record 6 of Set 7 | chenzhou
# Processing Record 7 of Set 7 | nyakahanga
# Processing Record 8 of Set 7 | spring valley
# Processing Record 9 of Set 7 | usinsk
# Processing Record 10 of Set 7 | agadez
# Processing Record 11 of Set 7 | jacobina
# Processing Record 12 of Set 7 | muzhi
# Processing Record 13 of Set 7 | tragana
# Processing Record 14 of Set 7 | mirnyy
# Processing Record 15 of Set 7 | cam pha
# City not found. Skipping...
# Processing Record 16 of Set 7 | kruisfontein
# Processing Record 17 of Set 7 | talnakh
# Processing Record 18 of Set 7 | chuy
# Processing Record 19 of Set 7 | kenai
# Processing Record 20 of Set 7 | la peca
# Processing Record 21 of Set 7 | shimoda
# Processing Record 22 of Set 7 | rafraf
# Processing Record 23 of Set 7 | lawton
# Processing Record 24 of Set 7 | emmett
# Processing Record 25 of Set 7 | aktau
# Processing Record 26 of Set 7 | koslan
# Processing Record 27 of Set 7 | guerrero negro
# Processing Record 28 of Set 7 | vestmannaeyjar
# Processing Record 29 of Set 7 | hamilton
# Processing Record 30 of Set 7 | okha
# Processing Record 31 of Set 7 | luderitz
# Processing Record 32 of Set 7 | iqaluit
# Processing Record 33 of Set 7 | puerto colombia
# Processing Record 34 of Set 7 | corralillo
# Processing Record 35 of Set 7 | hasaki
# Processing Record 36 of Set 7 | usvyaty
# Processing Record 37 of Set 7 | shieli
# Processing Record 38 of Set 7 | cortez
# Processing Record 39 of Set 7 | cabo san lucas
# Processing Record 40 of Set 7 | lagoa
# Processing Record 41 of Set 7 | santa helena de goias
# Processing Record 42 of Set 7 | orange walk
# Processing Record 43 of Set 7 | marsaxlokk
# Processing Record 44 of Set 7 | college
# Processing Record 45 of Set 7 | longlac
# City not found. Skipping...
# Processing Record 46 of Set 7 | longyearbyen
# Processing Record 47 of Set 7 | bani
# Processing Record 48 of Set 7 | quevedo
# Processing Record 49 of Set 7 | langsa
# Processing Record 50 of Set 7 | muttupet
# Processing Record 1 of Set 8 | hofn
# Processing Record 2 of Set 8 | doha
# Processing Record 3 of Set 8 | harindanga
# Processing Record 4 of Set 8 | harper
# Processing Record 5 of Set 8 | hohoe
# Processing Record 6 of Set 8 | bahia de caraquez
# Processing Record 7 of Set 8 | sassandra
# Processing Record 8 of Set 8 | najran
# Processing Record 9 of Set 8 | barcelona
# Processing Record 10 of Set 8 | watertown
# Processing Record 11 of Set 8 | aksarka
# Processing Record 12 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 13 of Set 8 | machaneng
# Processing Record 14 of Set 8 | bereznehuvate
# Processing Record 15 of Set 8 | mahadday weyne
# City not found. Skipping...
# Processing Record 16 of Set 8 | port macquarie
# Processing Record 17 of Set 8 | blagoyevo
# Processing Record 18 of Set 8 | aklavik
# Processing Record 19 of Set 8 | kologriv
# Processing Record 20 of Set 8 | portales
# Processing Record 21 of Set 8 | isangel
# Processing Record 22 of Set 8 | portobelo
# Processing Record 23 of Set 8 | zapolyarnyy
# Processing Record 24 of Set 8 | poya
# Processing Record 25 of Set 8 | villa altagracia
# Processing Record 26 of Set 8 | plettenberg bay
# Processing Record 27 of Set 8 | vao
# Processing Record 28 of Set 8 | katangli
# Processing Record 29 of Set 8 | linxia
# Processing Record 30 of Set 8 | kidal
# Processing Record 31 of Set 8 | winfield
# Processing Record 32 of Set 8 | amapa
# Processing Record 33 of Set 8 | pimentel
# Processing Record 34 of Set 8 | kamenka
# Processing Record 35 of Set 8 | marrakesh
# Processing Record 36 of Set 8 | vung tau
# Processing Record 37 of Set 8 | teknaf
# Processing Record 38 of Set 8 | bulgan
# Processing Record 39 of Set 8 | matadi
# Processing Record 40 of Set 8 | kavaratti
# Processing Record 41 of Set 8 | haines junction
# Processing Record 42 of Set 8 | ordu
# Processing Record 43 of Set 8 | cherskiy
# Processing Record 44 of Set 8 | vikhorevka
# Processing Record 45 of Set 8 | tome-acu
# City not found. Skipping...
# Processing Record 46 of Set 8 | vila franca do campo
# Processing Record 47 of Set 8 | vilhena
# Processing Record 48 of Set 8 | amarante do maranhao
# Processing Record 49 of Set 8 | upernavik
# Processing Record 50 of Set 8 | lata
# Processing Record 1 of Set 9 | dois vizinhos
# Processing Record 2 of Set 9 | flinders
# Processing Record 3 of Set 9 | batalha
# Processing Record 4 of Set 9 | druzhba
# Processing Record 5 of Set 9 | port hawkesbury
# Processing Record 6 of Set 9 | huangnihe
# Processing Record 7 of Set 9 | norman wells
# Processing Record 8 of Set 9 | shache
# Processing Record 9 of Set 9 | gamba
# Processing Record 10 of Set 9 | pitimbu
# Processing Record 11 of Set 9 | zhanjiang
# Processing Record 12 of Set 9 | heihe
# Processing Record 13 of Set 9 | mange
# Processing Record 14 of Set 9 | hermiston
# Processing Record 15 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 16 of Set 9 | brae
# Processing Record 17 of Set 9 | berlevag
# Processing Record 18 of Set 9 | taloqan
# Processing Record 19 of Set 9 | san carlos
# Processing Record 20 of Set 9 | lashio
# Processing Record 21 of Set 9 | ayagoz
# Processing Record 22 of Set 9 | khani
# Processing Record 23 of Set 9 | khandyga
# Processing Record 24 of Set 9 | andilamena
# Processing Record 25 of Set 9 | masterton
# Processing Record 26 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 27 of Set 9 | moosomin
# Processing Record 28 of Set 9 | grand gaube
# Processing Record 29 of Set 9 | kameda
# Processing Record 30 of Set 9 | vardo
# Processing Record 31 of Set 9 | semey
# Processing Record 32 of Set 9 | udachnyy
# Processing Record 33 of Set 9 | kangaatsiaq
# Processing Record 34 of Set 9 | acapulco
# Processing Record 35 of Set 9 | igrim
# Processing Record 36 of Set 9 | todos santos
# Processing Record 37 of Set 9 | jaguariaiva
# Processing Record 38 of Set 9 | sangar
# Processing Record 39 of Set 9 | hibbing
# Processing Record 40 of Set 9 | bambanglipuro
# Processing Record 41 of Set 9 | mrirt
# City not found. Skipping...
# Processing Record 42 of Set 9 | kutahya
# Processing Record 43 of Set 9 | lahaina
# Processing Record 44 of Set 9 | bagdarin
# Processing Record 45 of Set 9 | saldanha
# Processing Record 46 of Set 9 | churapcha
# Processing Record 47 of Set 9 | shunyi
# Processing Record 48 of Set 9 | dalbandin
# Processing Record 49 of Set 9 | ahuimanu
# Processing Record 50 of Set 9 | san rafael del sur
# Processing Record 1 of Set 10 | moindou
# Processing Record 2 of Set 10 | loreto
# Processing Record 3 of Set 10 | mill valley
# Processing Record 4 of Set 10 | sao joao del rei
# Processing Record 5 of Set 10 | murray bridge
# Processing Record 6 of Set 10 | beira
# Processing Record 7 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 8 of Set 10 | vachi
# Processing Record 9 of Set 10 | carballo
# Processing Record 10 of Set 10 | kosya
# City not found. Skipping...
# Processing Record 11 of Set 10 | merauke
# Processing Record 12 of Set 10 | mangaluru
# Processing Record 13 of Set 10 | talcahuano
# Processing Record 14 of Set 10 | mangaratiba
# Processing Record 15 of Set 10 | obihiro
# Processing Record 16 of Set 10 | kalmunai
# Processing Record 17 of Set 10 | dargaville
# Processing Record 18 of Set 10 | kotido
# Processing Record 19 of Set 10 | uchiza
# Processing Record 20 of Set 10 | ostrovnoy
# Processing Record 21 of Set 10 | manzil salim
# Processing Record 22 of Set 10 | orlik
# Processing Record 23 of Set 10 | kulhudhuffushi
# Processing Record 24 of Set 10 | hua hin
# Processing Record 25 of Set 10 | olinda
# Processing Record 26 of Set 10 | borogontsy
# Processing Record 27 of Set 10 | naze
# Processing Record 28 of Set 10 | laguna
# Processing Record 29 of Set 10 | ammon
# Processing Record 30 of Set 10 | ust-ishim
# Processing Record 31 of Set 10 | namatanai
# Processing Record 32 of Set 10 | baghdad
# Processing Record 33 of Set 10 | thunder bay
# Processing Record 34 of Set 10 | kikwit
# Processing Record 35 of Set 10 | aloja
# Processing Record 36 of Set 10 | gushikawa
# Processing Record 37 of Set 10 | moose factory
# Processing Record 38 of Set 10 | qeshm
# Processing Record 39 of Set 10 | wajir
# Processing Record 40 of Set 10 | gayny
# Processing Record 41 of Set 10 | moranbah
# Processing Record 42 of Set 10 | punto fijo
# Processing Record 43 of Set 10 | vicksburg
# Processing Record 44 of Set 10 | mahabad
# Processing Record 45 of Set 10 | roald
# Processing Record 46 of Set 10 | ponta delgada
# Processing Record 47 of Set 10 | pauini
# Processing Record 48 of Set 10 | noumea
# Processing Record 49 of Set 10 | muriti
# Processing Record 50 of Set 10 | tucurui
# Processing Record 1 of Set 11 | bheramara
# Processing Record 2 of Set 11 | iki-burul
# Processing Record 3 of Set 11 | tahmek
# Processing Record 4 of Set 11 | nova venecia
# Processing Record 5 of Set 11 | gulshat
# City not found. Skipping...
# Processing Record 6 of Set 11 | margate
# Processing Record 7 of Set 11 | kharabali
# Processing Record 8 of Set 11 | banyuwangi
# Processing Record 9 of Set 11 | sheffield
# Processing Record 10 of Set 11 | nicoya
# Processing Record 11 of Set 11 | muscat
# Processing Record 12 of Set 11 | krasnyy
# Processing Record 13 of Set 11 | aracuai
# Processing Record 14 of Set 11 | miles city
# Processing Record 15 of Set 11 | krasnoselkup
# Processing Record 16 of Set 11 | hanzhong
# Processing Record 17 of Set 11 | nome
# Processing Record 18 of Set 11 | mount gambier
# Processing Record 19 of Set 11 | lebanon
# Processing Record 20 of Set 11 | yar-sale
# Processing Record 21 of Set 11 | asau
# Processing Record 22 of Set 11 | great yarmouth
# Processing Record 23 of Set 11 | korla
# Processing Record 24 of Set 11 | la presa
# Processing Record 25 of Set 11 | lakatoro
# Processing Record 26 of Set 11 | itarema
# Processing Record 27 of Set 11 | izhma
# Processing Record 28 of Set 11 | cockburn town
# Processing Record 29 of Set 11 | sindor
# Processing Record 30 of Set 11 | deputatskiy
# Processing Record 31 of Set 11 | faanui
# Processing Record 32 of Set 11 | keti bandar
# Processing Record 33 of Set 11 | kondinskoye
# Processing Record 34 of Set 11 | bambous virieux
# Processing Record 35 of Set 11 | nyurba
# Processing Record 36 of Set 11 | raga
# Processing Record 37 of Set 11 | telde
# Processing Record 38 of Set 11 | edson
# Processing Record 39 of Set 11 | fianga
# City not found. Skipping...
# Processing Record 40 of Set 11 | arman
# Processing Record 41 of Set 11 | metro
# Processing Record 42 of Set 11 | hualmay
# Processing Record 43 of Set 11 | tura
# Processing Record 44 of Set 11 | touros
# Processing Record 45 of Set 11 | bonfim
# Processing Record 46 of Set 11 | moratuwa
# Processing Record 47 of Set 11 | bagotville
# Processing Record 48 of Set 11 | penzance
# Processing Record 49 of Set 11 | bijie
# Processing Record 50 of Set 11 | cap-aux-meules
# Processing Record 1 of Set 12 | kuala kedah
# Processing Record 2 of Set 12 | leshukonskoye
# Processing Record 3 of Set 12 | solnechnyy
# Processing Record 4 of Set 12 | manaure
# Processing Record 5 of Set 12 | sestri levante
# Processing Record 6 of Set 12 | dwarka
# Processing Record 7 of Set 12 | kailua
# Processing Record 8 of Set 12 | seoul
# Processing Record 9 of Set 12 | villa oliva
# City not found. Skipping...
# Processing Record 10 of Set 12 | bakel
# Processing Record 11 of Set 12 | portland
# Processing Record 12 of Set 12 | orissaare
# Processing Record 13 of Set 12 | tornio
# Processing Record 14 of Set 12 | beringovskiy
# Processing Record 15 of Set 12 | jacareacanga
# Processing Record 16 of Set 12 | fortuna
# Processing Record 17 of Set 12 | mwene-ditu
# Processing Record 18 of Set 12 | taltal
# Processing Record 19 of Set 12 | luganville
# Processing Record 20 of Set 12 | san luis
# Processing Record 21 of Set 12 | sioux lookout
# Processing Record 22 of Set 12 | robertsport
# Processing Record 23 of Set 12 | bathsheba
# Processing Record 24 of Set 12 | ksenyevka
# City not found. Skipping...
# Processing Record 25 of Set 12 | sabang
# Processing Record 26 of Set 12 | menongue
# Processing Record 27 of Set 12 | zdvinsk
# Processing Record 28 of Set 12 | agadir
# Processing Record 29 of Set 12 | honningsvag
# Processing Record 30 of Set 12 | cedar city
# Processing Record 31 of Set 12 | lakes entrance
# Processing Record 32 of Set 12 | limbus
# Processing Record 33 of Set 12 | rascani
# City not found. Skipping...
# Processing Record 34 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 35 of Set 12 | mpongwe
# Processing Record 36 of Set 12 | wundanyi
# Processing Record 37 of Set 12 | ambilobe
# Processing Record 38 of Set 12 | nelson bay
# Processing Record 39 of Set 12 | watrous
# Processing Record 40 of Set 12 | kudahuvadhoo
# Processing Record 41 of Set 12 | pachino
# Processing Record 42 of Set 12 | ijaki
# City not found. Skipping...
# Processing Record 43 of Set 12 | garden city
# Processing Record 44 of Set 12 | emba
# Processing Record 45 of Set 12 | abu kamal
# Processing Record 46 of Set 12 | termiz
# Processing Record 47 of Set 12 | comodoro rivadavia
# Processing Record 48 of Set 12 | mount isa
# Processing Record 49 of Set 12 | ostersund
# Processing Record 50 of Set 12 | nurlat
# Processing Record 1 of Set 13 | kawana waters
# City not found. Skipping...
# Processing Record 2 of Set 13 | quesnel
# Processing Record 3 of Set 13 | ilheus
# Processing Record 4 of Set 13 | nuuk
# Processing Record 5 of Set 13 | muros
# Processing Record 6 of Set 13 | mikun
# Processing Record 7 of Set 13 | bell ville
# Processing Record 8 of Set 13 | launceston
# Processing Record 9 of Set 13 | khor
# Processing Record 10 of Set 13 | chimbote
# Processing Record 11 of Set 13 | castelldefels
# Processing Record 12 of Set 13 | dunmore town
# Processing Record 13 of Set 13 | abu samrah
# Processing Record 14 of Set 13 | buala
# Processing Record 15 of Set 13 | ixtapa
# Processing Record 16 of Set 13 | marigot
# Processing Record 17 of Set 13 | ola
# Processing Record 18 of Set 13 | ibra
# Processing Record 19 of Set 13 | mao
# Processing Record 20 of Set 13 | saint-ambroise
# Processing Record 21 of Set 13 | mvomero
# Processing Record 22 of Set 13 | sterling
# Processing Record 23 of Set 13 | ocean city
# Processing Record 24 of Set 13 | fort saint james
# Processing Record 25 of Set 13 | tanggu
# Processing Record 26 of Set 13 | birao
# Processing Record 27 of Set 13 | lufkin
# Processing Record 28 of Set 13 | nelson
# Processing Record 29 of Set 13 | puerto baquerizo moreno
# Processing Record 30 of Set 13 | durazno
# Processing Record 31 of Set 13 | ternate
# Processing Record 32 of Set 13 | sokoni
# Processing Record 33 of Set 13 | goksun
# Processing Record 34 of Set 13 | rawson
# Processing Record 35 of Set 13 | vaitape
# Processing Record 36 of Set 13 | chicla
# Processing Record 37 of Set 13 | tingo maria
# Processing Record 38 of Set 13 | san andres
# Processing Record 39 of Set 13 | tubruq
# City not found. Skipping...
# Processing Record 40 of Set 13 | mendi
# Processing Record 41 of Set 13 | raudeberg
# Processing Record 42 of Set 13 | parintins
# Processing Record 43 of Set 13 | sidi ali
# Processing Record 44 of Set 13 | bershet
# Processing Record 45 of Set 13 | antigonish
# Processing Record 46 of Set 13 | delitzsch
# Processing Record 47 of Set 13 | nanortalik
# Processing Record 48 of Set 13 | mamburao
# Processing Record 49 of Set 13 | imeni telmana
# City not found. Skipping...
# Processing Record 50 of Set 13 | hervey bay
# Processing Record 1 of Set 14 | lavrentiya
# Processing Record 2 of Set 14 | nanakuli
# Processing Record 3 of Set 14 | collie
# Processing Record 4 of Set 14 | ekhabi
# Processing Record 5 of Set 14 | smithers
# Processing Record 6 of Set 14 | mandalgovi
# Processing Record 7 of Set 14 | catia la mar
# Processing Record 8 of Set 14 | sendhwa
# Processing Record 9 of Set 14 | bubaque
# Processing Record 10 of Set 14 | arlit
# Processing Record 11 of Set 14 | biloli
# Processing Record 12 of Set 14 | namtsy
# Processing Record 13 of Set 14 | bridgwater
# Processing Record 14 of Set 14 | aitape
# Processing Record 15 of Set 14 | qingdao
# Processing Record 16 of Set 14 | kemijarvi
# Processing Record 17 of Set 14 | arinos
# Processing Record 18 of Set 14 | olean
# Processing Record 19 of Set 14 | safaga
# Processing Record 20 of Set 14 | am timan
# Processing Record 21 of Set 14 | fevralsk
# City not found. Skipping...
# Processing Record 22 of Set 14 | pritzwalk
# Processing Record 23 of Set 14 | fairbanks
# Processing Record 24 of Set 14 | kimbe
# Processing Record 25 of Set 14 | mudgee
# Processing Record 26 of Set 14 | afmadu
# City not found. Skipping...
# Processing Record 27 of Set 14 | saint-pierre
# Processing Record 28 of Set 14 | calamar
# Processing Record 29 of Set 14 | praia da vitoria
# Processing Record 30 of Set 14 | svetlaya
# Processing Record 31 of Set 14 | maragogi
# Processing Record 32 of Set 14 | sobolevo
# Processing Record 33 of Set 14 | surt
# Processing Record 34 of Set 14 | itaqui
# Processing Record 35 of Set 14 | dong hoi
# Processing Record 36 of Set 14 | shubarkuduk
# Processing Record 37 of Set 14 | stolac
# Processing Record 38 of Set 14 | jishou
# Processing Record 39 of Set 14 | kalangala
# Processing Record 40 of Set 14 | santa marinella
# Processing Record 41 of Set 14 | viligili
# City not found. Skipping...
# Processing Record 42 of Set 14 | santa rosa
# Processing Record 43 of Set 14 | prieska
# Processing Record 44 of Set 14 | troitskoye
# Processing Record 45 of Set 14 | zihuatanejo
# Processing Record 46 of Set 14 | kazalinsk
# City not found. Skipping...
# Processing Record 47 of Set 14 | timbakion
# City not found. Skipping...
# Processing Record 48 of Set 14 | maloy
# Processing Record 49 of Set 14 | rosario
# Processing Record 50 of Set 14 | jacqueville
# Processing Record 1 of Set 15 | umm kaddadah
# Processing Record 2 of Set 15 | saleaula
# City not found. Skipping...
# Processing Record 3 of Set 15 | boa vista
# Processing Record 4 of Set 15 | teahupoo
# Processing Record 5 of Set 15 | kamina
# Processing Record 6 of Set 15 | paredon
# Processing Record 7 of Set 15 | rio gallegos
# Processing Record 8 of Set 15 | santo antonio do amparo
# Processing Record 9 of Set 15 | gat
# Processing Record 10 of Set 15 | bolungarvik
# City not found. Skipping...
# Processing Record 11 of Set 15 | haukipudas
# Processing Record 12 of Set 15 | belaya gora
# Processing Record 13 of Set 15 | tambura
# Processing Record 14 of Set 15 | jumla
# Processing Record 15 of Set 15 | mehamn
# Processing Record 16 of Set 15 | mecca
# Processing Record 17 of Set 15 | inuvik
# Processing Record 18 of Set 15 | saryshagan
# City not found. Skipping...
# Processing Record 19 of Set 15 | staryy nadym
# Processing Record 20 of Set 15 | dongsheng
# Processing Record 21 of Set 15 | novytsya
# Processing Record 22 of Set 15 | ramos arizpe
# Processing Record 23 of Set 15 | pushkino
# Processing Record 24 of Set 15 | umm lajj
# Processing Record 25 of Set 15 | vinces
# Processing Record 26 of Set 15 | puerto maldonado
# Processing Record 27 of Set 15 | leh
# Processing Record 28 of Set 15 | yeppoon
# Processing Record 29 of Set 15 | alexandria
# Processing Record 30 of Set 15 | chivilcoy
# Processing Record 31 of Set 15 | aswan
# Processing Record 32 of Set 15 | wittenberge
# Processing Record 33 of Set 15 | broken hill
# Processing Record 34 of Set 15 | lac du bonnet
# Processing Record 35 of Set 15 | palabuhanratu
# City not found. Skipping...
# Processing Record 36 of Set 15 | thinadhoo
# Processing Record 37 of Set 15 | champasak
# Processing Record 38 of Set 15 | miramar
# Processing Record 39 of Set 15 | batesville
# Processing Record 40 of Set 15 | chernyshevskiy
# Processing Record 41 of Set 15 | bhum
# Processing Record 42 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 43 of Set 15 | bandarbeyla
# Processing Record 44 of Set 15 | sestu
# Processing Record 45 of Set 15 | mabaruma
# Processing Record 46 of Set 15 | camopi
# Processing Record 47 of Set 15 | juneau
# Processing Record 48 of Set 15 | westport
# Processing Record 49 of Set 15 | araouane
# Processing Record 50 of Set 15 | port moresby
# Processing Record 1 of Set 16 | rio grande
# Processing Record 2 of Set 16 | dakoro
# Processing Record 3 of Set 16 | vyartsilya
# Processing Record 4 of Set 16 | tapes
# Processing Record 5 of Set 16 | palmer
# Processing Record 6 of Set 16 | morden
# Processing Record 7 of Set 16 | matamoros
# Processing Record 8 of Set 16 | cururupu
# Processing Record 9 of Set 16 | san carlos de bariloche
# Processing Record 10 of Set 16 | werda
# Processing Record 11 of Set 16 | yueyang
# Processing Record 12 of Set 16 | yurga
# Processing Record 13 of Set 16 | yerbogachen
# Processing Record 14 of Set 16 | dhidhdhoo
# Processing Record 15 of Set 16 | sawakin
# Processing Record 16 of Set 16 | maxixe
# Processing Record 17 of Set 16 | juan lacaze
# Processing Record 18 of Set 16 | satitoa
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
length_data = (len(city_data))
length_data
# Out:
# 710

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Castro      BR -24.7911  -50.0119     60.85        98          89
# 1   Mar Del Plata      AR -38.0023  -57.5575     62.10        70           0
# 2      Turukhansk      RU  65.8167   87.9833      0.43        93         100
# 3         Mandali      IQ  33.7499   45.5541     51.67        87          75
# 4    Punta Arenas      CL -53.1500  -70.9167     53.71        54          20
# 5       Busselton      AU -33.6500  115.3333     72.21        55          19
# 6      Nikolskoye      RU  59.7035   30.7861     28.80        92          26
# 7        Hermanus      ZA -34.4187   19.2345     58.80        72          72
# 8     Provideniya      RU  64.3833 -173.3000     12.38        83           9
# 9  Roanoke Rapids      US  36.4615  -77.6542     25.68        68           0
#
#    Wind Speed Current Description                 Date
# 0        9.17     overcast clouds  2022-12-25 00:31:33
# 1       14.00          light rain  2022-12-25 00:27:57
# 2       11.01     overcast clouds  2022-12-25 00:31:33
# 3        5.46          light rain  2022-12-25 00:31:34
# 4       27.63          few clouds  2022-12-25 00:30:01
# 5        5.97          few clouds  2022-12-25 00:31:35
# 6        6.87    scattered clouds  2022-12-25 00:31:35
# 7        9.24          light rain  2022-12-25 00:31:35
# 8       13.56           clear sky  2022-12-25 00:31:36
# 9       10.49           clear sky  2022-12-25 00:31:37

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description', 'Date'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]
# Display sample data
city_data_df.head(10)
# Out:
#              City Country                 Date      Lat       Lng  Max Temp  \
# 0          Castro      BR  2022-12-25 00:31:33 -24.7911  -50.0119     60.85
# 1   Mar Del Plata      AR  2022-12-25 00:27:57 -38.0023  -57.5575     62.10
# 2      Turukhansk      RU  2022-12-25 00:31:33  65.8167   87.9833      0.43
# 3         Mandali      IQ  2022-12-25 00:31:34  33.7499   45.5541     51.67
# 4    Punta Arenas      CL  2022-12-25 00:30:01 -53.1500  -70.9167     53.71
# 5       Busselton      AU  2022-12-25 00:31:35 -33.6500  115.3333     72.21
# 6      Nikolskoye      RU  2022-12-25 00:31:35  59.7035   30.7861     28.80
# 7        Hermanus      ZA  2022-12-25 00:31:35 -34.4187   19.2345     58.80
# 8     Provideniya      RU  2022-12-25 00:31:36  64.3833 -173.3000     12.38
# 9  Roanoke Rapids      US  2022-12-25 00:31:37  36.4615  -77.6542     25.68
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        98          89        9.17     overcast clouds
# 1        70           0       14.00          light rain
# 2        93         100       11.01     overcast clouds
# 3        87          75        5.46          light rain
# 4        54          20       27.63          few clouds
# 5        55          19        5.97          few clouds
# 6        92          26        6.87    scattered clouds
# 7        72          72        9.24          light rain
# 8        83           9       13.56           clear sky
# 9        68           0       10.49           clear sky

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Date                    object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
